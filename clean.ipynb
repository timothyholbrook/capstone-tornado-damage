# %%
# !pip install pandas

# %%
import pandas as pd

#Read data files
df = pd.read_csv('data/1950-23 damage_fatal_injury.csv')

# %%
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
df
# Out:
#    Unnamed: 0      Unnamed: 1     Unnamed: 2       Unnamed: 3  \
# 0        Year  # of Tornadoes  Direct Injury  Indirect Injury
# 1         All          76,533         98,125              273
# 2        2023           1,455            696                0
# 3        2022           1,380            315                3
# 4        2021           1,545            878                3
# ..        ...             ...            ...              ...
# 71       1954             609            715                0
# 72       1953             492          5,131                0
# 73       1952             272          1,916                0
# 74       1951             269            524                0
# 75       1950             223            659                0
#
#          Unnamed: 4         Unnamed: 5       Unnamed: 6    Unnamed: 7
# 0   Direct Fatality  Indirect Fatality  Property Damage   Crop Damage
# 1             6,202                 46  $71,815,382,290  $505,574,860
# ...
